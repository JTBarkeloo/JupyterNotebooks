# %% [markdown]
# # Single Hash for Level 1
# ## Double Hash for Level 2

# %% [markdown]
# $$ 2x^2 z_t +2 $$

# %%
x=2
3+x
# Out:
# 5

# %%
x
# Out:
# 2

# %%
print(2+2)
3+2
# Out:
# 4
# 5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.normal

# %%
X=np.random.normal(0,1,100)

# %%
plt.plot(X);

# %%
X=np.random.normal(0,1,100)
X2=np.random.normal(0,1,100)
plt.plot(X);
plt.plot(X2);
plt.xlabel('x')
plt.ylabel('ylabel')
# Out:
# Text(0, 0.5, 'ylabel')

# %%
np.mean(X)
# Out:
# 0.05979084832447233

# %%
x2=np.random.normal(0,1,1000000)

# %%
np.mean(x2)
# Out:
# 6.769953739614855e-05

# %%
np.std(x2)
# Out:
# 0.9997994062050762

# %%
data = get_pricing('MSFT', start_date='2012-1-1', end_date='2015-6-1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-2a6f498dd3b0> in <module>
# ----> 1 data = get_pricing('MSFT', start_date='2012-1-1', end_date='2015-6-1')
#
# NameError: name 'get_pricing' is not defined

# %%
plt.hist(x2,bins=20);
